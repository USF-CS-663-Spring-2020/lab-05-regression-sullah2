# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/Credit.csv")

# %%
df
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %%
df = df.iloc[:,1:]

# %%
X = df[['Income']].values.reshape(-1,1)
y = df[['Limit']].values.reshape(-1,1)

# %%
X, y
# Out:
# (array([[ 14.891],
#         [106.025],
#         [104.593],
#         [148.924],
#         [ 55.882],
#         [ 80.18 ],
#         [ 20.996],
#         [ 71.408],
#         [ 15.125],
#         [ 71.061],
#         [ 63.095],
#         [ 15.045],
#         [ 80.616],
#         [ 43.682],
#         [ 19.144],
#         [ 20.089],
#         [ 53.598],
#         [ 36.496],
#         [ 49.57 ],
#         [ 42.079],
#         [ 17.7  ],
#         [ 37.348],
#         [ 20.103],
#         [ 64.027],
#         [ 10.742],
#         [ 14.09 ],
#         [ 42.471],
#         [ 32.793],
#         [186.634],
#         [ 26.813],
#         [ 34.142],
#         [ 28.941],
#         [134.181],
#         [ 31.367],
#         [ 20.15 ],
#         [ 23.35 ],
#         [ 62.413],
#         [ 30.007],
#         [ 11.795],
#         [ 13.647],
#         [ 34.95 ],
#         [113.659],
#         [ 44.158],
#         [ 36.929],
#         [ 31.861],
#         [ 77.38 ],
#         [ 19.531],
# ...

# %%
plt.scatter(x=X, y = y, color = 'black')
plt.xlabel('Income')
plt.ylabel('Limit')
# Out:
# Text(0, 0.5, 'Limit')

# %%
r1 = sns.residplot(X, y)
r1.set(xlabel = 'Income', ylabel = 'Residual')
# Out:
# [Text(0, 0.5, 'Residual'), Text(0.5, 0, 'Income')]

# %%
reg_ = LinearRegression()

# %%
reg_.fit(X, y)
print(reg_.coef_)
print(reg_.intercept_)
# Out:
# [[51.8750206]]
# [2389.86940892]

# %%
X = df[['Rating']].values.reshape(-1,1)

# %%
plt.scatter(x=X, y = y, color = 'black')
plt.xlabel('Rating')
plt.ylabel('Limit')
# Out:
# Text(0, 0.5, 'Limit')

# %%
r1 = sns.residplot(X, y)
r1.set(xlabel = 'Rating', ylabel = 'Residual')
# Out:
# [Text(0, 0.5, 'Residual'), Text(0.5, 0, 'Rating')]

# %%
reg_.fit(X, y)
print(reg_.coef_)
print(reg_.intercept_)
# Out:
# [[14.87160712]]
# [-542.92822999]

# %%
X = df[['Cards']].values.reshape(-1,1)

# %%
plt.scatter(x=X, y = y, color = 'black')
plt.xlabel('Cards')
plt.ylabel('Limit')
# Out:
# Text(0, 0.5, 'Limit')

# %%
r1 = sns.residplot(X, y)
r1.set(xlabel = 'Cards', ylabel = 'Residual')
# Out:
# [Text(0, 0.5, 'Residual'), Text(0.5, 0, 'Cards')]

# %%
reg_.fit(X, y)
print(reg_.coef_)
print(reg_.intercept_)
# Out:
# [[17.22189457]]
# [4684.66624682]

# %%
X = df[['Age']].values.reshape(-1,1)

# %%
plt.scatter(x=X, y = y, color = 'black')
plt.xlabel('Age')
plt.ylabel('Limit')
# Out:
# Text(0, 0.5, 'Limit')

# %%
r1 = sns.residplot(X, y)
r1.set(xlabel = 'Age', ylabel = 'Residual')
# Out:
# [Text(0, 0.5, 'Residual'), Text(0.5, 0, 'Age')]

# %%
reg_.fit(X, y)
print(reg_.coef_)
print(reg_.intercept_)
# Out:
# [[13.49982568]]
# [3984.09845403]

# %%
X = df[['Education']].values.reshape(-1,1)

# %%
plt.scatter(x=X, y = y, color = 'black')
plt.xlabel('Education')
plt.ylabel('Limit')
# Out:
# Text(0, 0.5, 'Limit')

# %%
r1 = sns.residplot(X, y)
r1.set(xlabel = 'Education', ylabel = 'Residual')
# Out:
# [Text(0, 0.5, 'Residual'), Text(0.5, 0, 'Education')]

# %%
reg_.fit(X, y)
print(reg_.coef_)
print(reg_.intercept_)
# Out:
# [[-17.39235309]]
# [4969.52714909]
